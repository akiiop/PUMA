# %%
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt

# %%
lay=3;MC=5000; DimN=8
infi=np.zeros([MC,DimN,lay])
for j in range(lay):
    for i in range(DimN):
        file=h5.File("data/DataStatesDim="+str(i+3)+"Lay="+str(2+j)+".h5","r")
        infi[:,i,j]=file["infi"][:,:].min(axis=0)
        file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10068\2665638149.py in <module>
#       3 for j in range(lay):
#       4     for i in range(DimN):
# ----> 5         file=h5.File("data/DataStatesDim="+str(i+3)+"Lay="+str(2+j)+".h5","r")
#       6         infi[:,i,j]=file["infi"][:,:].min(axis=0)
#       7         file.close()
#
# ~\anaconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, **kwds)
#     531                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     532                                  fs_page_size=fs_page_size)
# --> 533                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     534
#     535             if isinstance(libver, tuple):
#
# ~\anaconda3\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     224         if swmr and swmr_support:
#     225             flags |= h5f.ACC_SWMR_READ
# --> 226         fid = h5f.open(name, flags, fapl=fapl)
#     227     elif mode == 'r+':
#     228         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = 'data/DataStatesDim=3Lay=2.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
x=infi.min(axis=0)
y=infi.max(axis=0)

infi=infi-x+1e-16

x=infi.min(axis=0)
y=infi.max(axis=0)
x
# Out:
# array([[1.e-16],
#        [1.e-16],
#        [1.e-16],
#        [1.e-16],
#        [1.e-16],
#        [1.e-16],
#        [1.e-16],
#        [1.e-16]])

# %%
#All dimensions histogram, all layers included

plt.matplotlib.rc("xtick",labelsize=14)
plt.matplotlib.rc("ytick",labelsize=14)


bins=30
fig,ax=plt.subplots(nrows=2,ncols=4,figsize=(20,10))
logbins=[np.logspace(np.log10(x[i,:].min()),np.log10(y[i,:].max()),bins) for i in range(DimN)]

colors=["yellowgreen", "darkred", "deepskyblue", "gold", "steelblue", "palegreen","navy","darkgray"]
labels=["2 layers","3 layers","4 layers"]
hatches=["/","\ ","|" ]


axs=ax.flatten()

for i in range(DimN):

    for j in range(lay):
        axs[i].hist(infi[:,i,j],
                    bins=logbins[i],
                    hatch=hatches[j],
                    histtype="step",
                    facecolor=colors[2-j],
                    edgecolor="k",
                    fill=True,
                    alpha= 0.7,
                    label=labels[j]
                   )
        
    axs[i].legend(handleheight=1.5,prop={"size":13})#prop={'size': 7})
    axs[i].set_xscale("log")
    axs[i].set_title("d="+str(i+3),size=16)

fig.tight_layout()
fig.savefig("PureStatesHist.pdf")

# %%
#inspection

bins=30
fig,ax=plt.subplots(nrows=2,ncols=4,figsize=(20,10))
logbins=[np.logspace(np.log10(x[i,1]),np.log10(y[i,1]),bins) for i in range(DimN)]
colors=["yellowgreen", "darkred", "deepskyblue", "gold", "steelblue", "palegreen","navy","darkgray"]
labels=["2 layers","3 layers"]
hatches=[" /","\ "]

axs=ax.flatten()
for i in range(DimN):
    axs[i].hist(infi[:,i,1],bins=logbins[i],color=colors[i])    
    axs[i].set_xscale("log")
    axs[i].set_title("d="+str(i+3),size=16)
    
fig.tight_layout()
fig.savefig("his3lay.pdf")

# %%
infi[:,0]
# Out:
# array([  1.31904371e-02,   1.00000000e-16,   1.47530617e-02,
#          1.34422692e-02,   6.73521104e-07,   7.66133815e-16,
#          5.44089210e-16,   1.22857277e-02,   8.18182183e-03,
#          7.66133815e-16,   5.44089210e-16,   3.73870418e-04,
#          5.44089210e-16,   5.44089210e-16,   5.44089210e-16,
#          3.22044605e-16,   3.22044605e-16,   7.66133815e-16,
#          5.44089210e-16,   5.44089210e-16,   5.44089210e-16,
#          5.44089210e-16,   7.66133815e-16,   5.44089210e-16,
#          5.44089210e-16,   6.85688056e-02,   3.22044605e-16,
#          5.44089210e-16,   2.76789785e-03,   1.80171755e-02,
#          7.66133815e-16,   2.68233646e-02,   7.66133815e-16,
#          7.66133815e-16,   5.44089210e-16,   7.66133815e-16,
#          7.66133815e-16,   8.84494147e-03,   5.44089210e-16,
#          5.44089210e-16,   5.44089210e-16,   5.44089210e-16,
#          7.66133815e-16,   3.22044605e-16,   5.44089210e-16,
#          7.66133815e-16,   1.10595924e-02,   5.44089210e-16,
#          5.44089210e-16,   2.21240464e-02])
